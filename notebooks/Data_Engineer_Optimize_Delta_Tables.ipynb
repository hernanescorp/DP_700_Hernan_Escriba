# %% [markdown]
# # **_Optimizing Delta Tables_**

# %%
# Disable Optimize Write at the Spark session level
spark.conf.set("spark.microsoft.delta.optimizeWrite.enabled", False)

# Enable Optimize Write at the Spark session level
spark.conf.set("spark.microsoft.delta.optimizeWrite.enabled", True)

print(spark.conf.get("spark.microsoft.delta.optimizeWrite.enabled"))
# Out:
# StatementMeta(, 723a0089-e587-44a1-aea4-07843a4e695d, 3, Finished, Available, Finished)
# true

# %% [markdown]
# # **VACUUM**

# %% [markdown]
# <u>To wach all the transactions history.</u>

# %%
# %%sql
# DESCRIBE HISTORY LH_CU_Lakegistica.DIM_Suppliers_References
# Out:
# StatementMeta(, 0e8a9f19-c8fd-4fc9-ab68-acdbe60f4e89, 2, Finished, Available, Finished)
# <Spark SQL result set with 12 rows and 15 fields>

# %% [markdown]
# <mark>**Use of VACUUM**</mark>

# %%
# %%sql
# VACUUM LH_CU_Lakegistica.DIM_Suppliers_References RETAIN 168 HOURS;
# Out:
# StatementMeta(, 0e8a9f19-c8fd-4fc9-ab68-acdbe60f4e89, 4, Finished, Available, Finished)
# <Spark SQL result set with 1 rows and 1 fields>

# %% [markdown]
# Wach the history again.

# %%
# %%sql
# DESCRIBE HISTORY LH_CU_Lakegistica.DIM_Suppliers_References
# Out:
# StatementMeta(, 0e8a9f19-c8fd-4fc9-ab68-acdbe60f4e89, 5, Finished, Available, Finished)
# <Spark SQL result set with 15 rows and 15 fields>

# %% [markdown]
# # **Creating Partitions in Delta Tables**
